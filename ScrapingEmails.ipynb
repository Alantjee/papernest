# %% [markdown]
# <a href="https://colab.research.google.com/github/Alantjee/papernest/blob/main/ScrapingEmails.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1- Loading libraries

# %%
import re
import time
from tokenize import Ignore
import requests
from bs4 import BeautifulSoup
import pandas as pd
import queue
import threading
from urllib.parse import urlsplit
import numpy


from google.colab import auth
from google.colab import files
import gspread
from google.auth import default
import gspread_dataframe as gd

# %% [markdown]
# ## 2- Choice of the scope (italy, france, spain)

# %%
scope = input('Enter the scope of your analysis (italy, france, spain, uk): uk ')
print('The scope chosen is: ' + scope)
# Out:
# Enter the scope of your analysis (italy, france, spain, uk): france
# The scope chosen is: france

# %% [markdown]
# ## 3- Data loading URL

# %%
# In pd.read_csv: replace the link (in public sharing mode) with the link of your file with the websites to crawls (replace with export?format=csv&)
url_link = 'https://docs.google.com/spreadsheets/d/1OMGESeQfuDTmrbH0lamI4zURQtO0KzkBb8Wc3dDa_5U/export?format=csv&gid=0'

# %% [markdown]
# ## 4- Functions

# %%
class myThread (threading.Thread):
    def __init__(self, scraper, id, queue_lock, dataframe_lock):
      threading.Thread.__init__(self)
      self.scraper = scraper
      self.id = id
      self.queue_lock = queue_lock
      self.dataframe_lock = dataframe_lock
      self.alive = True
      self.regex_domain = '(\.[^\.]*)$'
      self.regex_words = '([a-zA-Z0-9_]+)[^a-zA-Z0-9_]'
      
    def run(self):
        
        while self.alive:
            
            url = self.next_link()
            
            if url != None:
            
                try:
                    path, base_url = self.split_url(url)
                    
                    text, dataframe_new_emails = self.scraper.crawl_url_address(url)
                    dataframe_new_emails = self.filter_emails(dataframe_new_emails)
                    print('{} emails found'.format(len(dataframe_new_emails)))
                    self.update_emails(dataframe_new_emails, base_url)
                    
                    links = self.scraper.crawl_url_link(text, base_url, path)
                    print('{} links found'.format(len(links)))
                    self.update_links(links)

                except:
                    pass
                
            
    def next_link(self):
        self.queue_lock.acquire()
        print(f"Queue Size: {self.scraper.links.qsize()}")
        if self.scraper.links.qsize() > 0:
            temp = self.scraper.links.get()
            print("Thread {} scraping : {}".format(self.id, temp[0]))
            self.queue_lock.release()
            return temp[0]
        else:
            self.alive = False
            return None
    
    def split_url(self, url):
        parts = urlsplit(url)
        base_url = "{0.scheme}://{0.netloc}".format(parts)
        if '/' in parts.path:
            path = url[:url.rfind('/')+1]
        else:
            path = url
        
        return path, base_url
    
    def filter_emails(self, dataframe):
        dataframe['filter'] = dataframe['mail'].apply(self.regex)
        return dataframe[dataframe['filter']].drop('filter', axis='columns', errors='ignore')
        
    def regex(self, mail):
        words = re.findall(self.regex_words, mail)
        domain = re.findall(self.regex_domain, mail)
        bool_word = False
        for val in words:
            if val in self.scraper.keywords_to_avoid:
                bool_word = True
        bool_domain = (domain in self.scraper.domains_to_avoid)
        bool_mail = (mail in self.scraper.mails_to_avoid)
        bool_length = (len(mail)<7)
        
        return not(bool_word or bool_domain or bool_mail or bool_length)
        
    def update_emails(self, dataframe_new_emails, base_url):
        
        if len(dataframe_new_emails)>0:
            dataframe_new_emails['base_url'] = base_url
            self.dataframe_lock.acquire()
            self.scraper.emails = pd.concat([self.scraper.emails, dataframe_new_emails], ignore_index=True).drop_duplicates(subset=['mail'])    
            self.scraper.emails = self.scraper.emails.sort_values(by='base_url').reset_index(drop=True)
            self.scraper.emails.to_csv('emails.csv', header=True)
            self.dataframe_lock.release()
        
    def update_links(self, links):
        
        if len(links)>0:
            self.queue_lock.acquire()
            for val in links:
                path, base_url = self.split_url(val)
                if base_url in list(self.scraper.seen_links.keys()):
                    if not(val in self.scraper.seen_links[base_url]) and len(self.scraper.seen_links[base_url])<100:
                        self.scraper.links.put([val, base_url])
                        self.scraper.seen_links[base_url].append(val)
                else:
                    self.scraper.links.put([val, base_url])
                    self.scraper.seen_links[base_url] = [val]
                    
                    for keyword in self.scraper.contact_keywords:
                        self.scraper.links.put([base_url + '/' + keyword, base_url])
                        self.scraper.seen_links[base_url].append(base_url + '\\' + keyword)
                    
            self.queue_lock.release()
    


class ScrapingEmails:
    def __init__(self, urls, scope, nbcrawlers = 10):
        
        self.nbcrawlers = nbcrawlers
        
        self.urls = urls
        self.seen_links = {}
        for val in self.urls:
            self.seen_links[val] = [val]
        self.links = queue.Queue()
        self.threads = []
        self.queue_lock = threading.Lock()
        self.dataframe_lock = threading.Lock()
        
        self.emails = pd.DataFrame()

        auth.authenticate_user()
        creds, _ = default()
        gc = gspread.authorize(creds)
        gc.create("emails")
        self.sheet = gc.open("emails").sheet1
        
        if scope == 'italy' or scope == 'Italy':
            self.to_avoid = pd.read_csv('https://docs.google.com/spreadsheets/d/1ouKXLiPILTSQDg0BSnsu7tJrIwQfjQKNggY06KQdEE8/export?format=csv&gid=939556409')
            self.contact_keywords = ['contatti.html' , 'dove-siamo-e-contatti/' , 'contatti/' , 'contact/' , 'contatti' , '#contatti' , 'contact' , '#!/contacts' , '#contact' , 'Contatti.aspx' , 'chi-siamo/', 'privacy-policy/' , '#!/privacy' , 'privacyPolicy' , 'cookie-policy/' , 'all-rights-reserved-copyright' , 'Cookies.aspx' , 'about/']
        elif scope == 'spain' or scope == 'Spain':
            self.to_avoid = pd.read_csv('https://docs.google.com/spreadsheets/d/1ouKXLiPILTSQDg0BSnsu7tJrIwQfjQKNggY06KQdEE8/export?format=csv&gid=825351815')
            self.contact_keywords = ['contatti.html' , 'dove-siamo-e-contatti/' , 'contatti/' , 'contact/' , 'contatti' , '#contatti' , 'contact' , '#!/contacts' , '#contact' , 'Contatti.aspx' , 'chi-siamo/', 'privacy-policy/' , '#!/privacy' , 'privacyPolicy' , 'cookie-policy/' , 'all-rights-reserved-copyright' , 'Cookies.aspx' , 'about/']
        elif scope == 'france' or scope == 'France':
            self.contact_keywords = ['mentions-legales/','contact/','informations-legales/','index.php/contact/' , 'mentions.html' , 'politique-de-confidentialite/' , 'contact.php/' , 'contact.htm/' , 'contacts.html/' , 'contact.html/' , 'cgv/']
            self.to_avoid = pd.read_csv('https://docs.google.com/spreadsheets/d/1ouKXLiPILTSQDg0BSnsu7tJrIwQfjQKNggY06KQdEE8/export?format=csv&gid=0')
        elif scope == 'uk' or scope == 'UK':
            self.contact_keywords = ['contatti.html' , 'dove-siamo-e-contatti/' , 'contatti/' , 'contact/' , 'contatti' , '#contatti' , 'contact' , '#!/contacts' , '#contact' , 'Contatti.aspx' , 'chi-siamo/', 'privacy-policy/' , '#!/privacy' , 'privacyPolicy' , 'cookie-policy/' , 'all-rights-reserved-copyright' , 'Cookies.aspx' , 'about/']
            self.to_avoid = pd.read_csv('https://docs.google.com/spreadsheets/d/1ouKXLiPILTSQDg0BSnsu7tJrIwQfjQKNggY06KQdEE8/export?format=csv&gid=1873485851')

        self.mails_to_avoid = self.to_avoid['mails_to_avoid'].dropna().tolist()
        self.keywords_to_avoid = self.to_avoid['keywords_to_avoid'].dropna().tolist()
        self.domains_to_avoid = self.to_avoid['domains_to_avoid'].dropna().tolist()
        
    def pre_run(self):
        self.filling_queue()
        self.creating_threads()
        
    def post_run(self):
        for thread in self.threads:
            thread.join()
        
        
    def creating_threads(self):
        for i in range(self.nbcrawlers):
            thread = myThread(self, i, self.queue_lock, self.dataframe_lock)
            self.threads.append(thread)
            thread.start()
            time.sleep(10)
            
    def filling_queue(self):
        for val in self.urls:
            self.links.put([val, val])
            
        
    def crawl_url_address(self, url):
        response = requests.get(url)
        new_emails = re.findall(r'[a-zA-Z0-9_.+-]+(?:@|\(a\)|\(at\)|\( at \)|\( a \)|\( @ \)|&#64;|\( arobase \)|\(arobase\)|\[a\]|\[ a \]|\[at\]|\[ at \])(?!domain|email)[a-zA-Z0-9_.+-]+(?:\.|\( point \)|\(point\)|\(dot\))(?!jpg|jpeg|png|gif|docx)[a-zA-Z]{1,4}', response.text, re.I)
        dataframe_new_emails = pd.DataFrame({'mail': new_emails}).drop_duplicates(subset=['mail'])
        return response.text, dataframe_new_emails
    
    def crawl_url_link(self, text, base_url, path):
        soup = BeautifulSoup(text, 'html.parser')
        links = []
        for anchor in soup.find_all("a"):
            
            if "href" in anchor.attrs:
              link = anchor.attrs["href"]
              
            else:
                link = ''
                
            if link.startswith('/'):
                link = base_url + link
                
            elif not link.startswith('http'):
                link = path + link
            links.append(link)
        links = numpy.random.choice(links, size=50).tolist()
        return links
    
ndd = pd.read_csv(url_link, on_bad_lines='skip', header=0)
url = ndd['URL'].apply(lambda x: "{0.scheme}://{0.netloc}".format(urlsplit(x))).unique().tolist()
scraper = ScrapingEmails(url, scope)
scraper.pre_run()
scraper.post_run()
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#
# Queue Size: 3318
# Thread 9 scraping : https://www.monde-diplomatique.fr/2019/04/BRISSAUD/59741
# 0 emails found
# 50 links found
# Queue Size: 3318
# Thread 5 scraping : https://www.monde-diplomatique.fr/publications
# 0 emails found
# 50 links found
# Queue Size: 3342
# Thread 4 scraping : https://www.monde-diplomatique.fr/int#Macédoine
# 50 links found
# Queue Size: 3341
# Thread 1 scraping : https://www.monde-diplomatique.fr/index.php/contact/ecouter/Podcast_diplo/2022-04-Endeweld_diplo.mp3
# 50 links found
# Queue Size: 3354
# Thread 0 scraping : https://www.monde-diplomatique.fr/diplo/apropos
# 0 emails found
# 50 links found
# Queue Size: 3367
# Thread 2 scraping : https://www.monde-diplomatique.fr/revues/foreignaffairs
# 3 emails found
# 0 emails found
# 50 links found
# Queue Size: 3379
# Thread 8 scraping : https://www.monde-diplomatique.fr/revues/newleftreview
# 0 emails found
# 50 links found0 emails found
#
# Queue Size: 3391
# Thread 3 scraping : https://boutique.monde-diplomatique.fr/50 links found
#
# Queue Size: 3390
# Thread 5 scraping : https://www.monde-diplomatique.fr/2011/10/CHETERIAN/21074
# 0 emails found
# 0 emails found50 links found
# Queue Size: 3404
# Thread 9 scraping : https://www.monde-diplomatique.fr/int#Allemagne
#
# 50 links found
# Queue Size: 3403
# Thread 2 scraping : https://www.monde-diplomatique.fr/int#Pologne
# 50 links found
# Queue Size: 3405
# Thread 0 scraping : https://www.monde-diplomatique.fr//blog.mondediplo.net
# 0 emails found
# 50 links found
# Queue Size: 3405
# Thread 4 scraping : https://www.monde-diplomatique.fr/2022/04/PIRONET/64577
# 0 emails found
# 50 links found
# Queue Size: 3416
# Thread 8 scraping : https://www.monde-diplomatique.fr/cartes/ble-russe-ukrainien
# 0 emails found
# 0 emails found
# Queue Size: 3415
# Thread 0 scraping : https://www.monde-diplomatique.fr/2022/04/FAUJOUR/64579
# 50 links found
# Queue Size: 3474
# Thread 5 scraping : https://www.monde-diplomatique.fr//boutique.monde-diplomatique.fr/reabonnement/
# 0 emails found
# 50 links found
# Queue Size: 3473
# Thread 4 scraping : https://www.monde-diplomatique.fr/carnet/2020-01-15-La-liberte-reduite-au-portefeuille
# 0 emails found
# 50 links found
# Queue Size: 3473
# Thread 8 scraping : https://www.monde-diplomatique.fr/carnet/2019-03-25-Russiagate-la-debacle
# 0 emails found0 emails found0 emails found
#
# Queue Size: 3472
# Thread 5 scraping : https://www.monde-diplomatique.fr/carnet/?debut_posts=96#pagination_posts
#
# 50 links found50 links found
# Queue Size: 3471
# Thread 9 scraping : https://www.monde-diplomatique.fr/dossier/gaza
#
# Queue Size: 3470
# Thread 2 scraping : https://www.monde-diplomatique.fr/carnet/?debut_posts=48#pagination_posts
# 0 emails found0 emails found
#
# 50 links found
# 50 links found
# Queue Size: 3470
# Thread 0 scraping : https://www.monde-diplomatique.fr/dossier/etatsunis2008
# Queue Size: 3469
# Thread 3 scraping : https://www.monde-diplomatique.fr/info-diplo/
# 0 emails found
# 0 emails found
# 50 links found
# Queue Size: 3469
# Thread 1 scraping : https://www.monde-diplomatique.fr/dossier/krach2008
# 0 emails found
# Queue Size: 3468
# Thread 5 scraping : https://www.monde-diplomatique.fr/dossier/GMT
# 50 links found
# Queue Size: 3468
# Thread 4 scraping : https://www.monde-diplomatique.fr/carnet/?debut_posts=72#pagination_posts
# 0 emails found
# Queue Size: 3467
# Thread 2 scraping : https://www.monde-diplomatique.fr/connexion
# 0 emails found
# 50 links found
# Queue Size: 3467
# Thread 8 scraping : https://www.monde-diplomatique.fr/carnet/?debut_posts=84#pagination_posts
# 0 emails found
# 0 emails found
# 50 links found
# Queue Size: 3563
# Thread 9 scraping : https://www.monde-diplomatique.fr/dossier/tueriesparis50 links found
#
# Queue Size: 3732
# Thread 0 scraping : https://www.monde-diplomatique.fr/carnet/2019-12-04-Retraites-le-point-de-non-retour
# 0 emails found
# Queue Size: 3731
# Thread 4 scraping : https://www.monde-diplomatique.fr/carnet/?debut_posts=12#pagination_posts
# 0 emails found
# 0 emails found
# Queue Size: 3730
# Thread 8 scraping : https://www.monde-diplomatique.fr/dossier/France2022
# 50 links found
# Queue Size: 3729
# Thread 2 scraping : https://www.monde-diplomatique.fr/carnet/?debut_posts=36#pagination_posts
# 0 emails found
# 0 emails found
# 50 links found
# Queue Size: 3728
# Thread 3 scraping : https://www.monde-diplomatique.fr/carnet/2020-04-16-Sepulveda
# 50 links found0 emails found
# 0 emails found
# Queue Size: 3764
#
# Thread 5 scraping : https://www.monde-diplomatique.fr/cartes/sanctions-internationales
# 50 links found
# Queue Size: 3776
# Thread 9 scraping : https://www.monde-diplomatique.fr/cartes/recherche/cartes?s=Transports%20%7C%20villes
# 50 links found
# Queue Size: 3776
# Thread 0 scraping : https://www.monde-diplomatique.fr/cartes/recherche/cartes?s=Droits%20humains
# 0 emails found
# Queue Size: 3775
# Thread 4 scraping : https://www.monde-diplomatique.fr/carnet/2015-05-25-Libre-echange
# 0 emails found
# Queue Size: 3774
# Thread 2 scraping : https://www.monde-diplomatique.fr//boutique.monde-diplomatique.fr/abonnements/
# 0 emails found
# 50 links found
# Queue Size: 3773
# Thread 8 scraping : https://www.monde-diplomatique.fr/cartes/proche-orient-divers-et-militaire
# 0 emails found0 emails found
# Queue Size: 3772
#
# 0 emails found
# Thread 0 scraping : https://www.monde-diplomatique.fr/cartes/fractures-est-ouest
# 0 emails found
# Queue Size: 3771
# Thread 9 scraping : https://www.monde-diplomatique.fr/cartes/recherche/cartes?s=Social%20%7C%20soci%C3%A9t%C3%A9
# 50 links found50 links found
# Queue Size: 3771
# Thread 3 scraping : https://www.monde-diplomatique.fr/cartes/age-ecart
#
# Queue Size: 3770
# Thread 5 scraping : https://www.monde-diplomatique.fr/cartes/recherche/cartes?s=Monde&mots%5B%5D=Monde
# 0 emails found
# Queue Size: 3769
# Thread 2 scraping : http://help.opera.com/Windows/12.10/fr/notrack.html
# 0 emails found
# 50 links found
# Queue Size: 3769
# Thread 4 scraping : http://help.opera.com/mentions-legales/
# 0 emails found
# 50 links found
# Queue Size: 3768
# Thread 1 scraping : http://help.opera.com/contact/
# 0 emails found
# 50 links found
# Queue Size: 3768
# Thread 8 scraping : http://help.opera.com/informations-legales/
# 0 emails found
# Queue Size: 3767
# Thread 9 scraping : http://help.opera.com/index.php/contact/
# 0 emails found0 emails found
#
# Queue Size: 3766
# Thread 5 scraping : http://help.opera.com/mentions.html50 links found
#
# Queue Size: 3767
# Thread 0 scraping : http://help.opera.com/politique-de-confidentialite/
# 0 emails found
# 50 links found
# Queue Size: 3766
# Thread 3 scraping : http://help.opera.com/contact.php/
# 0 emails found
# 50 links found
# Queue Size: 3840
# Thread 1 scraping : http://help.opera.com/contact.htm/
# 0 emails found
# 50 links found
# Queue Size: 3869
# Thread 2 scraping : http://help.opera.com/contacts.html/
# 0 emails found
# 50 links found
# Queue Size: 3914
# Thread 4 scraping : http://help.opera.com/contact.html/
# 0 emails found
# 50 links found
# Queue Size: 3929
# Thread 8 scraping : http://help.opera.com/cgv/
# 0 emails found
# 50 links found
# Queue Size: 3937
# Thread 0 scraping : https://boutique.monde-diplomatique.fr/contacts/
# 0 emails found
# 50 links found
# Queue Size: 3936
# Thread 5 scraping : http://www.monde-diplomatique.fr
# 0 emails found
# 50 links found
# Queue Size: 3937
# Thread 2 scraping : http://docs.info.apple.com/article.html?path=Safari/3.0/fr/9277.html
# Queue Size: 3936
# Thread 2 scraping : http://docs.info.apple.com/mentions-legales/
# Queue Size: 3935
# Thread 2 scraping : http://docs.info.apple.com/contact/
# Queue Size: 3934
# Thread 2 scraping : http://docs.info.apple.com/informations-legales/
# Queue Size: 3933
# Thread 2 scraping : http://docs.info.apple.com/index.php/contact/
# Queue Size: 3932
# Thread 2 scraping : http://docs.info.apple.com/mentions.html
# Queue Size: 3931
# Thread 2 scraping : http://docs.info.apple.com/politique-de-confidentialite/
# Queue Size: 3930
# Thread 2 scraping : http://docs.info.apple.com/contact.php/
# Queue Size: 3929
# Thread 2 scraping : http://docs.info.apple.com/contact.htm/
# Queue Size: 3928
# Thread 2 scraping : http://docs.info.apple.com/contacts.html/
# Queue Size: 3927
# Thread 2 scraping : http://docs.info.apple.com/contact.html/
# Queue Size: 3926
# Thread 2 scraping : http://docs.info.apple.com/cgv/
# Queue Size: 3925
# Thread 2 scraping : https://support.google.com/chrome/answer/114836?
# 0 emails found
# 0 emails found
# 50 links found
# Queue Size: 3926
# Thread 1 scraping : https://support.google.com/mentions-legales/
# 50 links found
# Queue Size: 3928
# Thread 3 scraping : https://support.google.com/contact/
# 2 emails found
# 0 emails found
# 0 emails found0 emails found
# 50 links found
#
# Queue Size: 3967
# Thread 2 scraping : https://support.google.com/informations-legales/
# 50 links found
# Queue Size: 3966
# Thread 0 scraping : https://support.google.com/index.php/contact/
# 0 emails found
# 50 links found50 links found50 links found
# Queue Size: 3990
# Thread 5 scraping : https://support.google.com/mentions.html
#
#
# Queue Size: 3990
# Thread 4 scraping : https://support.google.com/politique-de-confidentialite/
# Queue Size: 3989
# Thread 9 scraping : https://support.google.com/contact.php/
# 2 emails found
# 2 emails found
# 0 emails found
# 50 links found
# Queue Size: 4006
# Thread 3 scraping : https://support.google.com/contact.htm/
# 50 links found
# Queue Size: 4005
# Thread 8 scraping : https://support.google.com/contacts.html/
# 50 links found
# Queue Size: 4064
# Thread 1 scraping : https://support.google.com/contact.html/
# 2 emails found2 emails found
#
# 2 emails found
# 50 links found
# Queue Size: 4093
# Thread 5 scraping : https://support.google.com/cgv/
# 50 links found
# Queue Size: 4095
# Thread 0 scraping : https://flic.kr/p/9v9W5g
# 50 links found
# Queue Size: 4110
# Thread 2 scraping : https://flic.kr/mentions-legales/
# 2 emails found
# 2 emails found
# 50 links found
# Queue Size: 4109
# Thread 9 scraping : https://flic.kr/contact/
# 2 emails found
# 2 emails found
# 2 emails found
# 50 links found
# Queue Size: 4108
# Thread 4 scraping : https://flic.kr/informations-legales/
# 50 links found
# Queue Size: 4108
# Thread 8 scraping : https://flic.kr/index.php/contact/
# 50 links found
# Queue Size: 4107
# Thread 3 scraping : https://flic.kr/mentions.html
# 50 links found
# Queue Size: 4106
# Thread 1 scraping : https://flic.kr/politique-de-confidentialite/
# 0 emails found
# 2 emails found
# 50 links found0 emails found
#
# Queue Size: 4158
# Thread 2 scraping : https://flic.kr/contact.php/
# 50 links found50 links found
# Queue Size: 4194
# Thread 0 scraping : https://flic.kr/contact.htm/
#
# Queue Size: 4193
# Thread 5 scraping : https://flic.kr/contacts.html/
# 0 emails found0 emails found
#
# 0 emails found0 emails found
#
# 50 links found
# Queue Size: 4199
# 50 links found
# 50 links found
# 0 emails foundThread 1 scraping : https://flic.kr/contact.html/
# Queue Size: 42010 emails found
#
#
# Thread 8 scraping : https://flic.kr/cgv/
# Queue Size: 4201
# 50 links foundThread 4 scraping : http://support.mozilla.org/fr/kb/Activer%20et%20d%C3%A9sactiver%20les%20cookies
#
# 50 links found
# Queue Size: 420250 links found
#
# Thread 2 scraping : http://support.mozilla.org/mentions-legales/
# Queue Size: 4201
# Thread 3 scraping : http://support.mozilla.org/contact/
# Queue Size: 4218
# Thread 9 scraping : http://support.mozilla.org/informations-legales/
# 0 emails found
# 50 links found0 emails found
# Queue Size: 4219
#
# 50 links foundThread 5 scraping : http://support.mozilla.org/index.php/contact/
#
# Queue Size: 4220
# Thread 0 scraping : http://support.mozilla.org/mentions.html
# 0 emails found
# 50 links found
# Queue Size: 4221
# Thread 1 scraping : http://support.mozilla.org/politique-de-confidentialite/
# 0 emails found
# 0 emails found
# 0 emails found
# 50 links found
# Queue Size: 4271
# Thread 2 scraping : http://support.mozilla.org/contact.php/
# 0 emails found
# 50 links found
# 50 links foundQueue Size: 4301
# Thread 9 scraping : http://support.mozilla.org/contact.htm/
#
# Queue Size: 4307
# Thread 3 scraping : http://support.mozilla.org/contacts.html/
# 0 emails found
# 0 emails found
# 50 links found
# Queue Size: 4308
# Thread 5 scraping : http://support.mozilla.org/contact.html/
# 0 emails found
# 50 links found
# 50 links foundQueue Size: 4308
#
# Thread 0 scraping : http://support.mozilla.org/cgv/
# Queue Size: 4348
# Thread 4 scraping : https://privacy.microsoft.com/fr-fr/windows-10-microsoft-edge-and-privacy
# 50 links found
# Queue Size: 4350
# Thread 8 scraping : https://privacy.microsoft.com/mentions-legales/
# 0 emails found
# 50 links found
# Queue Size: 4350
# Thread 1 scraping : https://privacy.microsoft.com/contact/
# 0 emails found
# Queue Size: 4349
# Thread 8 scraping : https://privacy.microsoft.com/informations-legales/
# 0 emails found
# 50 links found
# Queue Size: 4552
# Thread 4 scraping : https://privacy.microsoft.com/index.php/contact/
# 0 emails found
# Queue Size: 4551
# Thread 1 scraping : https://privacy.microsoft.com/mentions.html
# 0 emails found0 emails found
#
# 50 links found
# Queue Size: 4550
# Thread 9 scraping : https://privacy.microsoft.com/politique-de-confidentialite/
# 50 links found
# Queue Size: 4550
# Thread 2 scraping : https://privacy.microsoft.com/contact.php/
# 0 emails found
# 0 emails found
# 0 emails found
# 50 links found
# Queue Size: 4552
# Thread 3 scraping : https://privacy.microsoft.com/contact.htm/
# 50 links found
# Queue Size: 4552
# Thread 5 scraping : https://privacy.microsoft.com/contacts.html/
# 50 links found
# Queue Size: 4553
# Thread 0 scraping : https://privacy.microsoft.com/contact.html/
# 0 emails found
# Queue Size: 4552
# Thread 4 scraping : https://privacy.microsoft.com/cgv/
# 0 emails found
# Queue Size: 4551
# Thread 1 scraping : https://www.facebook.com/sharer/sharer.php?u=https://www.monde-diplomatique.fr/58712
# 0 emails found
# Queue Size: 4550
# Thread 8 scraping : http://windows.microsoft.com/fr-fr/internet-explorer/use-tracking-protection#ie=ie-11
# 0 emails found
# Queue Size: 4549
# Thread 9 scraping : http://windows.microsoft.com/mentions-legales/
# 0 emails found
# Queue Size: 4548
# Thread 2 scraping : http://windows.microsoft.com/contact/
# 0 emails found
# Queue Size: 4547
# Thread 3 scraping : http://windows.microsoft.com/informations-legales/
# 0 emails found
# Queue Size: 4546
# Thread 0 scraping : http://windows.microsoft.com/index.php/contact/
# 0 emails found
# Queue Size: 4545
# Thread 4 scraping : http://windows.microsoft.com/mentions.html0 emails found
#
# Queue Size: 4544
# Thread 5 scraping : http://windows.microsoft.com/politique-de-confidentialite/
# 0 emails found
# 50 links found
# Queue Size: 4545
# Thread 1 scraping : http://windows.microsoft.com/contact.php/
# 0 emails found0 emails found
#
# 0 emails found
# 0 emails found
# 0 emails found
# 0 emails found
# 50 links found0 emails found
#
# Queue Size: 4635
# 0 emails found
# 50 links found
# Thread 8 scraping : http://windows.microsoft.com/contact.htm/
# Queue Size: 4740
# Thread 9 scraping : http://windows.microsoft.com/contacts.html/
# 50 links found
# Queue Size: 4784
# Thread 1 scraping : http://windows.microsoft.com/contact.html/
# 50 links found
# Queue Size: 4798
# 50 links found
# Thread 4 scraping : http://windows.microsoft.com/cgv/
# Queue Size: 4804
# Thread 0 scraping : https://www.amis.monde-diplomatique.fr/rubrique86
# 50 links found
# Queue Size: 482150 links found
#
# 50 links found
# Thread 3 scraping : https://www.amis.monde-diplomatique.fr/Pour-un-systeme-educatif-democratique-1-Martine-Boudet.html
# Queue Size: 4826
# Thread 2 scraping : https://www.amis.monde-diplomatique.fr/Ukraine-Russie-choc-de-memoires-et-conflit-de-recits.html
# Queue Size: 4840
# Thread 5 scraping : https://www.amis.monde-diplomatique.fr/article6108
# 0 emails found
# 0 emails found
# 0 emails found
# 0 emails found
# 50 links found
# Queue Size: 4841
# Thread 4 scraping : https://www.amis.monde-diplomatique.fr/rubrique1
# 1 emails found
# 50 links found50 links found
# Queue Size: 4844
#
# 50 links found
# Thread 8 scraping : https://polemixetlavoixoff.com/afghanistan-cimetiere-des-empires/
# Queue Size: 4846
# Thread 9 scraping : https://polemixetlavoixoff.com/mentions-legales/
# Queue Size: 4847
# Thread 1 scraping : https://polemixetlavoixoff.com/contact/
# 50 links found
# Queue Size: 4848
# Thread 3 scraping : https://polemixetlavoixoff.com/informations-legales/
# 0 emails found
# 1 emails found50 links found
#
# Queue Size: 4847
# Thread 0 scraping : https://polemixetlavoixoff.com/index.php/contact/
# 1 emails found
# 50 links found
# Queue Size: 4847
# Thread 5 scraping : https://polemixetlavoixoff.com/mentions.html
# 50 links found
# Queue Size: 4859
# Thread 2 scraping : https://polemixetlavoixoff.com/politique-de-confidentialite/
# 0 emails found
# 1 emails found
# 50 links found
# Queue Size: 4858
# Thread 4 scraping : https://polemixetlavoixoff.com/contact.php/
# 50 links found
# Queue Size: 4928
# Thread 1 scraping : https://polemixetlavoixoff.com/contact.htm/
# 0 emails found
# 0 emails found
# 50 links found0 emails found
#
# Queue Size: 495750 links found
#
# 50 links found
# Thread 8 scraping : https://polemixetlavoixoff.com/contacts.html/
# Queue Size: 4957
# Thread 3 scraping : https://polemixetlavoixoff.com/contact.html/
# Queue Size: 4957
# Thread 9 scraping : https://polemixetlavoixoff.com/cgv/
# 0 emails found1 emails found
#
# 50 links found
# 0 emails foundQueue Size: 4957
# Thread 5 scraping : https://www.amis.monde-diplomatique.fr/article4913
#
# 50 links found
# Queue Size: 4958
# Thread 0 scraping : https://www.amis.monde-diplomatique.fr/Table-ronde-sur-les-sondages.html
# 50 links found
# Queue Size: 4958
# Thread 2 scraping : http://twitter.com/amisdiplo
# 0 emails found
# 50 links found
# Queue Size: 4958
# Thread 1 scraping : http://twitter.com/mentions-legales/
# 0 emails found
# 50 links found
# Queue Size: 4958
# Thread 4 scraping : http://twitter.com/contact/
# 0 emails found
# 50 links found
# Queue Size: 4958
# Thread 9 scraping : http://twitter.com/informations-legales/
# 0 emails found
# 0 emails found
# 50 links found50 links found
#
# Queue Size: 4958
# Thread 3 scraping : http://twitter.com/index.php/contact/
# Queue Size: 4958
# Thread 8 scraping : http://twitter.com/mentions.html
# 0 emails found
# 50 links found
# 0 emails found
# Queue Size: 4957
# Thread 1 scraping : http://twitter.com/politique-de-confidentialite/
# 50 links found
# Queue Size: 4956
# Thread 0 scraping : http://twitter.com/contact.php/1 emails found
#
# 0 emails found
# 50 links found
# Queue Size: 4955
# Thread 4 scraping : http://twitter.com/contact.htm/
# 0 emails found
# 50 links found50 links found
# Queue Size: 4967
# Thread 5 scraping : http://twitter.com/contacts.html/
#
# Queue Size: 4966
# Thread 9 scraping : http://twitter.com/contact.html/
# 0 emails found
# 50 links found
# Queue Size: 4965
# Thread 3 scraping : http://twitter.com/cgv/
# 0 emails found
# 50 links found
# Queue Size: 4964
# Thread 4 scraping : https://www.amis.monde-diplomatique.fr/L-OTAN-ressuscitee.html
# 0 emails found
# 50 links found
# Queue Size: 4963
# Thread 0 scraping : https://www.amis.monde-diplomatique.fr/Apres-les-elections-presidentielles-tableau-de-la-France-neoliberale.html
# 0 emails found
# 50 links found
# Queue Size: 4962
# Thread 8 scraping : https://www.amis.monde-diplomatique.fr/rubrique194
# 0 emails found
# 50 links found
# 0 emails foundQueue Size: 4961
# 50 links found
#
# Thread 1 scraping : https://www.amis.monde-diplomatique.fr/spip.php?page=adherer
# Queue Size: 4960
# Thread 2 scraping : https://www.amis.monde-diplomatique.fr/spip.php?page=rencontres
# 0 emails found
# 0 emails found
# 0 emails found
# 50 links found
# Queue Size: 4959
# Thread 5 scraping : https://www.amis.monde-diplomatique.fr/Discussion-sous-les-cocotiers.html
# 50 links found1 emails found
#
# 50 links found
# Queue Size: 4958
# Thread 9 scraping : https://www.amis.monde-diplomatique.fr/article6499
# 1 emails foundQueue Size: 4957
# Thread 3 scraping : https://www.amis.monde-diplomatique.fr/Dernieres-nouvelles-du-mensonge-7657.html
#
# 50 links found
# Queue Size: 4958
# Thread 4 scraping : https://www.amis.monde-diplomatique.fr/A-demain-mon-amour-7620.html
# 50 links found
# Queue Size: 4958
# Thread 0 scraping : https://www.amis.monde-diplomatique.fr/concours/
# 1 emails found0 emails found
#
# 50 links found
# Queue Size: 4958
# Thread 1 scraping : http://www.facebook.com/Amis.Monde.diplomatique50 links found
#
# Queue Size: 4957
# Thread 8 scraping : http://www.facebook.com/mentions-legales/
# 1 emails found
# 1 emails found
# 25 emails found
# 50 links found
# Queue Size: 4956
# Thread 2 scraping : http://www.facebook.com/contact/
# 1 emails found1 emails found
#
# 50 links found50 links found
# Queue Size: 4967
#
# 50 links found
# Thread 0 scraping : http://www.facebook.com/informations-legales/
# Queue Size: 4980
# Thread 4 scraping : http://www.facebook.com/index.php/contact/0 emails found
#
# Queue Size: 4991
# Thread 5 scraping : http://www.facebook.com/mentions.html
# 50 links found
# Queue Size: 5015
# Thread 3 scraping : http://www.facebook.com/politique-de-confidentialite/
# 0 emails found
# 50 links found
# Queue Size: 503550 links found
#
# Thread 8 scraping : http://www.facebook.com/contact.php/
# Queue Size: 5035
# Thread 9 scraping : http://www.facebook.com/contact.htm/
# 0 emails found
# Queue Size: 5034
# 0 emails found
# Thread 1 scraping : http://www.facebook.com/contacts.html/
# 50 links found
# Queue Size: 5038
# Thread 2 scraping : http://www.facebook.com/contact.html/
# 0 emails found
# 0 emails found0 emails found
#
# 50 links found
# Queue Size: 5042
# Thread 5 scraping : http://www.facebook.com/cgv/
# 0 emails found
# 50 links found0 emails found
# 0 emails found
#
# Queue Size: 5045
# Thread 8 scraping : https://www.amis.monde-diplomatique.fr/rubrique210
# 50 links found0 emails found
#
# Queue Size: 5047
# Thread 0 scraping : https://www.amis.monde-diplomatique.fr/article130 emails found50 links found
#
#
# 50 links foundQueue Size: 5049
# Thread 3 scraping : https://www.amis.monde-diplomatique.fr/Pour-un-systeme-educatif-democratique-2-Alain-Refalo.html
#
# Queue Size: 5051
# Thread 9 scraping : https://www.spip.net/
# 50 links found
# Queue Size: 5054
# Thread 4 scraping : https://www.spip.net/mentions-legales/
# 50 links found50 links found
# Queue Size: 5059
# Thread 1 scraping : https://www.spip.net/contact/
#
# Queue Size: 5059
# Thread 2 scraping : https://www.spip.net/informations-legales/
# 0 emails found
# 50 links found
# Queue Size: 5064
# Thread 5 scraping : https://www.spip.net/index.php/contact/
# 0 emails found
# 50 links found0 emails found
# Queue Size: 5091
#
# Thread 4 scraping : https://www.spip.net/mentions.html
# 50 links found
# Queue Size: 5119
# Thread 1 scraping : https://www.spip.net/politique-de-confidentialite/
# 1 emails found0 emails found
#
# 0 emails found
# 50 links found
# Queue Size: 5160
# Thread 9 scraping : https://www.spip.net/contact.php/
# 50 links found50 links found
# Queue Size: 5161
# Thread 3 scraping : https://www.spip.net/contact.htm/
#
# Queue Size: 5161
# Thread 2 scraping : https://www.spip.net/contacts.html/
# 1 emails found
# 50 links found
# Queue Size: 5161
# Thread 0 scraping : https://www.spip.net/contact.html/
# 0 emails found
# 50 links found
# Queue Size: 5160
# Thread 8 scraping : https://www.spip.net/cgv/
# 0 emails found
# 50 links found0 emails found
# Queue Size: 5159
#
# 0 emails found
# Thread 2 scraping : https://www.amis.monde-diplomatique.fr/spip.php?page=videos
# Queue Size: 5158
# Thread 4 scraping : https://www.amis.monde-diplomatique.fr/Feu-sur-les-libertes-7639.html
# Queue Size: 5157
# 0 emails found
# Thread 9 scraping : https://www.amis.monde-diplomatique.fr/L-Union-Europeenne-et-les-crises-de-l-Etat-de-droit-1-2-La-conference.html
# Queue Size: 5156
# Thread 3 scraping : https://www.amis.monde-diplomatique.fr/mentions-legales/rubrique1
# 0 emails found
# Queue Size: 5155
# Thread 0 scraping : https://www.amis.monde-diplomatique.fr/mentions-legales/rubrique194
# 0 emails found
# 50 links found
# Queue Size: 5154
# Thread 1 scraping : https://moncompte.amis.monde-diplomatique.fr/
# 0 emails found
# Queue Size: 5153
# Thread 8 scraping : https://moncompte.amis.monde-diplomatique.fr/mentions-legales/
# 0 emails found0 emails found
#
# 1 emails found
# 50 links found
# Queue Size: 5152
# 50 links found
# Thread 4 scraping : https://moncompte.amis.monde-diplomatique.fr/contact/
# Queue Size: 5151
# Thread 2 scraping : https://moncompte.amis.monde-diplomatique.fr/informations-legales/
# 50 links found
# Queue Size: 5152
# Thread 9 scraping : https://moncompte.amis.monde-diplomatique.fr/index.php/contact/
# 0 emails found
# 50 links found
# Queue Size: 5151
# Thread 3 scraping : https://moncompte.amis.monde-diplomatique.fr/mentions.html
# 1 emails found0 emails found
#
# 50 links found
# Queue Size: 5168
# Thread 9 scraping : https://moncompte.amis.monde-diplomatique.fr/politique-de-confidentialite/
# 0 emails found
# 50 links found
# Queue Size: 5173
# Thread 1 scraping : https://moncompte.amis.monde-diplomatique.fr/contact.php/0 emails found
#
# 0 emails found
# 50 links found0 emails found
#
# Queue Size: 5175
# Thread 4 scraping : https://moncompte.amis.monde-diplomatique.fr/contact.htm/
# 50 links found
# Queue Size: 5177
# Thread 8 scraping : https://moncompte.amis.monde-diplomatique.fr/contacts.html/
# 50 links found
# Queue Size: 5179
# Thread 2 scraping : https://moncompte.amis.monde-diplomatique.fr/contact.html/
# 0 emails found
# 50 links found
# Queue Size: 5178
# Thread 0 scraping : https://moncompte.amis.monde-diplomatique.fr/cgv/
# 50 links found
# Queue Size: 5177
# Thread 3 scraping : https://www.amis.monde-diplomatique.fr/mentions-legales/article7342
# 0 emails found
# Queue Size: 5176
# Thread 1 scraping : https://www.amis.monde-diplomatique.fr/mentions-legales/rubrique2
# 0 emails found
# 50 links found
# Queue Size: 5176
# Thread 4 scraping : https://www.amis.monde-diplomatique.fr/mentions-legales/rubrique210
# 0 emails found
# 50 links found0 emails found
# 50 links found
# Queue Size: 5176
# Thread 8 scraping : https://www.amis.monde-diplomatique.fr/mentions-legales/article13
#
# Queue Size: 51780 emails found
# 50 links found
#
# Thread 9 scraping : https://www.amis.monde-diplomatique.fr/mentions-legales/concours
# Queue Size: 5178
# Thread 2 scraping : https://www.amis.monde-diplomatique.fr/mentions-legales/article6499
# 0 emails found
# 50 links found
# Queue Size: 5180
# Thread 0 scraping : https://www.instagram.com/amis_du_monde_diplomatique/
# 1 emails found
# 50 links found
# Queue Size: 5180
# Thread 3 scraping : https://www.instagram.com/mentions-legales/
# 0 emails found
# 0 emails found
# Queue Size: 5179
# Thread 0 scraping : https://www.instagram.com/contact/
# 50 links found
# 0 emails foundQueue Size: 5178
#
# Thread 9 scraping : https://www.instagram.com/informations-legales/
# Queue Size: 5177
# Thread 3 scraping : https://www.instagram.com/index.php/contact/
# 0 emails found
# 1 emails found
# 0 emails found
# 1 emails found
# 50 links found50 links found
# Queue Size: 5176
# Thread 4 scraping : https://www.instagram.com/mentions.html
#
# Queue Size: 5175
# Thread 1 scraping : https://www.instagram.com/politique-de-confidentialite/
# 50 links found
# 50 links found
# Queue Size: 5174
# Thread 8 scraping : https://www.instagram.com/contact.php/
# Queue Size: 5173
# Thread 2 scraping : https://www.instagram.com/contact.htm/
# 0 emails found
# Queue Size: 5172
# Thread 3 scraping : https://www.instagram.com/contacts.html/
# 0 emails found
# Queue Size: 5171
# Thread 0 scraping : https://www.instagram.com/contact.html/
# 0 emails found
# Queue Size: 5170
# Thread 8 scraping : https://www.instagram.com/cgv/
# 0 emails found
# Queue Size: 5169
# Thread 4 scraping : https://www.amis.monde-diplomatique.fr/mentions-legales/article6108
# 0 emails found
# Queue Size: 5168
# Thread 9 scraping : https://www.youtube.com/channel/UCVqaxIdcM0EpQ2QSzKHvqeg
# Queue Size: 5167
# Thread 5 scraping : https://www.youtube.com/mentions-legales/
# 0 emails found0 emails found
# Queue Size: 5166
#
# Thread 1 scraping : https://www.youtube.com/contact/
# Queue Size: 5165
# Thread 2 scraping : https://www.youtube.com/informations-legales/
# 0 emails found
# 0 emails found
# Queue Size: 51640 emails found
# 0 emails found
#
# Thread 3 scraping : https://www.youtube.com/index.php/contact/
# Queue Size: 5163
# 0 emails found
# Thread 8 scraping : https://www.youtube.com/mentions.html
# Queue Size: 5162
# Thread 5 scraping : https://www.youtube.com/politique-de-confidentialite/
# Queue Size: 5161
# Thread 0 scraping : https://www.youtube.com/contact.php/
# 50 links found
# Queue Size: 5184
# Thread 9 scraping : https://www.youtube.com/contact.htm/1 emails found
#
# 0 emails found
# Queue Size: 5183
# Thread 2 scraping : https://www.youtube.com/contacts.html/
# 50 links found0 emails found
# Queue Size: 5182
# Thread 3 scraping : https://www.youtube.com/contact.html/
#
# Queue Size: 5181
# Thread 4 scraping : https://www.youtube.com/cgv/
# 0 emails found
# 0 emails found0 emails found
# Queue Size: 5180
# Thread 5 scraping : https://www.amis.monde-diplomatique.fr/mentions-legales/rubrique3
#
# Queue Size: 5179
# Thread 0 scraping : https://www.amis.monde-diplomatique.fr/mentions-legales/
# 0 emails found
# Queue Size: 5178
# 50 links found
# Thread 8 scraping : https://www.amis.monde-diplomatique.fr/contact/rubrique3
# 0 emails found
# Queue Size: 5177
# Thread 1 scraping : https://www.amis.monde-diplomatique.fr/contact/rubrique1
# 0 emails found
# Queue Size: 5176
# Thread 2 scraping : https://www.amis.monde-diplomatique.fr/contact/article13
# Queue Size: 5175
# Thread 9 scraping : https://www.amis.monde-diplomatique.fr/contact/article7342
# 0 emails found
# Queue Size: 5174
# Thread 3 scraping : https://www.amis.monde-diplomatique.fr/contact/spip.php?page=videos
# 0 emails found
# 50 links found
# Queue Size: 5173
# Thread 4 scraping : https://www.amis.monde-diplomatique.fr/contact/rubrique210
# 0 emails found
# 50 links found
# Queue Size: 5172
# Thread 3 scraping : https://www.amis.monde-diplomatique.fr/contact/article4913
# 0 emails found
# 50 links found
# Queue Size: 5171
# Thread 0 scraping : https://www.amis.monde-diplomatique.fr/contact/rubrique194
# 1 emails found
# 0 emails found
# 1 emails found
# 50 links found50 links found
# Queue Size: 5172
#
# Thread 9 scraping : https://www.amis.monde-diplomatique.fr/contact/spip.php?page=adherer
# Queue Size: 5171
# 0 emails found
# 0 emails foundThread 1 scraping : https://www.amis.monde-diplomatique.fr/contact/article6499
# 50 links found
# 50 links found
# Queue Size: 5170
#
# 50 links found
# Thread 2 scraping : https://www.amis.monde-diplomatique.fr/contact/rubrique86
# Queue Size: 5169
# Thread 8 scraping : https://www.amis.monde-diplomatique.fr/contact/
# Queue Size: 5168
# Thread 5 scraping : https://www.amis.monde-diplomatique.fr/contact/rubrique2
# 0 emails found
# 50 links found
# Queue Size: 5167
# Thread 4 scraping : https://www.amis.monde-diplomatique.fr/contact/concours
# 1 emails found
# 50 links found0 emails found
# Queue Size: 5166
#
# Thread 3 scraping : https://www.amis.monde-diplomatique.fr/contact/rubrique130
# 1 emails found
# 50 links found
# Queue Size: 5165
# Thread 9 scraping : https://www.amis.monde-diplomatique.fr/informations-legales/spip.php?page=adherer
# 50 links found
# Queue Size: 5164
# Thread 0 scraping : https://www.amis.monde-diplomatique.fr/informations-legales/rubrique3
# 0 emails found
# 50 links found
# Queue Size: 5163
# Thread 8 scraping : https://www.amis.monde-diplomatique.fr/informations-legales/rubrique1
# 0 emails found
# 50 links found
# Queue Size: 5162
# Thread 1 scraping : https://www.amis.monde-diplomatique.fr/informations-legales/spip.php?page=videos
# 0 emails found
# 50 links found
# Queue Size: 5161
# Thread 4 scraping : https://www.amis.monde-diplomatique.fr/informations-legales/rubrique2
# 0 emails found0 emails found
# 50 links found
# Queue Size: 5160
# Thread 5 scraping : https://www.amis.monde-diplomatique.fr/informations-legales/article7342
#
# 50 links found
# Queue Size: 5159
# Thread 2 scraping : https://www.amis.monde-diplomatique.fr/informations-legales/article6499
# 0 emails found
# 50 links found
# Queue Size: 5158
# Thread 9 scraping : https://www.amis.monde-diplomatique.fr/informations-legales/article13
# 0 emails found
# 50 links found0 emails found
#
# Queue Size: 5157
# Thread 0 scraping : https://www.amis.monde-diplomatique.fr/informations-legales/article4913
# 50 links found
# Queue Size: 5156
# Thread 8 scraping : https://www.amis.monde-diplomatique.fr/informations-legales/article7341
# 0 emails found0 emails found
#
# 50 links found
# Queue Size: 515550 links found
#
# Thread 3 scraping : https://www.amis.monde-diplomatique.fr/informations-legales/rubrique86
# Queue Size: 5154
# Thread 1 scraping : https://www.amis.monde-diplomatique.fr/informations-legales/rubrique210
# 0 emails found
# 1 emails found
# 50 links found50 links found0 emails found
# Queue Size: 5155
# Thread 5 scraping : https://www.amis.monde-diplomatique.fr/informations-legales/
#
# Queue Size: 5154
# Thread 4 scraping : https://www.amis.monde-diplomatique.fr/informations-legales/rubrique194
#
# 50 links found
# Queue Size: 5153
# Thread 2 scraping : https://www.amis.monde-diplomatique.fr/informations-legales/article6498
# 1 emails found
# 50 links found
# Queue Size: 5154
# Thread 9 scraping : https://www.amis.monde-diplomatique.fr/index.php/contact/Table-ronde-sur-les-sondages.html
# 1 emails found
# 50 links found
# Queue Size: 5155
# Thread 0 scraping : https://www.amis.monde-diplomatique.fr/index.php/contact/Tout-commence-au-Chili-une-victoire-ecrasante-de-la-gauche.html
# 0 emails found
# 50 links found
# Queue Size: 5156
# Thread 8 scraping : https://www.amis.monde-diplomatique.fr/index.php/contact/spip.php?page=rencontres
# 0 emails found0 emails found
#
# 50 links found
# Queue Size: 5155
# Thread 1 scraping : https://www.amis.monde-diplomatique.fr/index.php/contact/Discussion-sous-les-cocotiers.html
# 50 links found
# Queue Size: 5154
# Thread 3 scraping : https://www.amis.monde-diplomatique.fr/index.php/contact/Apres-les-elections-presidentielles-tableau-de-la-France-neoliberale.html
# 2 emails found
# 0 emails found
# 50 links found
# Queue Size: 5154
# Thread 2 scraping : https://www.amis.monde-diplomatique.fr/index.php/contact/A-demain-mon-amour-7620.html
# 50 links found
# Queue Size: 5153
# Thread 5 scraping : https://www.amis.monde-diplomatique.fr/index.php/contact/Pour-un-systeme-educatif-democratique-1-Martine-Boudet.html
# 1 emails found
# 0 emails found
# 50 links found
# 50 links foundQueue Size: 5152
#
# Thread 9 scraping : https://www.amis.monde-diplomatique.fr/index.php/contact/rubrique194
# Queue Size: 5151
# Thread 4 scraping : https://www.amis.monde-diplomatique.fr/index.php/contact/Feu-sur-les-libertes-7639.html
# 0 emails found
# 50 links found
# Queue Size: 5150
# Thread 0 scraping : https://www.amis.monde-diplomatique.fr/index.php/contact/spip.php?page=videos
# 0 emails found
# 0 emails found
# 50 links found
# Queue Size: 5149
# Thread 3 scraping : https://www.amis.monde-diplomatique.fr/index.php/contact/spip.php?page=adherer1 emails found
#
# 50 links found
# Queue Size: 5148
# Thread 1 scraping : https://www.amis.monde-diplomatique.fr/index.php/contact/article7342
# 0 emails found0 emails found50 links found
#
# Queue Size: 5147
# Thread 8 scraping : https://www.amis.monde-diplomatique.fr/index.php/contact/L-OTAN-ressuscitee.html
#
# 50 links found50 links found
# Queue Size: 5146
# Thread 2 scraping : https://www.amis.monde-diplomatique.fr/index.php/contact/article13
#
# Queue Size: 5145
# Thread 5 scraping : https://www.amis.monde-diplomatique.fr/index.php/contact/Pour-un-systeme-educatif-democratique-2-Alain-Refalo.html
# 0 emails found
# 50 links found
# Queue Size: 51440 emails found
# 0 emails found
#
# 50 links foundThread 9 scraping : https://x5to3.mjt.lu/nl2/x5to3/5ygvy.html
#
# Queue Size: 5143
# Thread 4 scraping : https://x5to3.mjt.lu/mentions-legales/
# 50 links found
# Queue Size: 5142
# Thread 0 scraping : https://x5to3.mjt.lu/contact/
# 0 emails found
# 50 links found
# Queue Size: 5141
# Thread 3 scraping : https://x5to3.mjt.lu/informations-legales/
# 0 emails found
# 1 emails found
# 50 links found
# 0 emails found
# Queue Size: 514050 links found
# Thread 1 scraping : https://x5to3.mjt.lu/index.php/contact/
#
# Queue Size: 5156
# Thread 4 scraping : https://x5to3.mjt.lu/mentions.html
# 1 emails found50 links found
# Queue Size: 5155
#
# Thread 8 scraping : https://x5to3.mjt.lu/politique-de-confidentialite/
# 1 emails found0 emails found
#
# 50 links found
# Queue Size: 5155
# Thread 0 scraping : https://x5to3.mjt.lu/contact.php/
# 0 emails found
# 50 links found
# Queue Size: 5154
# 50 links found
# 1 emails found
# Thread 5 scraping : https://x5to3.mjt.lu/contact.htm/
# Queue Size: 5154
# Thread 3 scraping : https://x5to3.mjt.lu/contacts.html/
# 50 links found
# Queue Size: 5153
# Thread 2 scraping : https://x5to3.mjt.lu/contact.html/
# 50 links found
# Queue Size: 5168
# Thread 9 scraping : https://x5to3.mjt.lu/cgv/
# 1 emails found
# 50 links found
# Queue Size: 5168
# Thread 4 scraping : https://www.amis.monde-diplomatique.fr/index.php/contact/Dernieres-nouvelles-du-mensonge-7657.html
# 1 emails found
# 1 emails found
# 50 links found
# Queue Size: 5168
# Thread 1 scraping : https://www.amis.monde-diplomatique.fr/index.php/contact/Apres-la-presidentielle-que-faire.html
# 50 links found
# Queue Size: 5168
# Thread 8 scraping : https://www.amis.monde-diplomatique.fr/index.php/contact/rubrique1
# 1 emails found
# 50 links found
# Queue Size: 5168
# Thread 0 scraping : https://www.amis.monde-diplomatique.fr/index.php/contact/Feu-sur-les-libertes-7637.html
# 1 emails found
# 1 emails found
# 1 emails found
# 1 emails found
# 50 links found50 links found
# Queue Size: 5168
# Thread 5 scraping : https://www.amis.monde-diplomatique.fr/index.php/contact/Ukraine-Russie-choc-de-memoires-et-conflit-de-recits.html
#
# Queue Size: 516850 links found
#
# Thread 9 scraping : https://www.amis.monde-diplomatique.fr/index.php/contact/rubrique3
# Queue Size: 516850 links found
#
# Thread 3 scraping : https://www.amis.monde-diplomatique.fr/index.php/contact/article4913
# Queue Size: 5168
# Thread 2 scraping : https://www.amis.monde-diplomatique.fr/index.php/contact/article6499
# 0 emails found
# 50 links found
# Queue Size: 5167
# Thread 4 scraping : https://www.amis.monde-diplomatique.fr/index.php/contact/#
# 0 emails found
# 0 emails found
# 0 emails found
# 50 links found
# Queue Size: 5166
# Thread 1 scraping : https://flic.kr/p/2kz63fA
# 50 links found
# Queue Size: 5165
# Thread 8 scraping : https://www.facebook.com/sharer/sharer.php?u=https://www.monde-diplomatique.fr/64464
# 0 emails found
# 50 links found0 emails found
# Queue Size: 5164
# Thread 0 scraping : https://www.youtube.com/channel/UCJZ-hXrLYUFHBnkM0Vb2mqw
#
# 0 emails found
# 50 links found0 emails found
#
# Queue Size: 5163
# Thread 2 scraping : http://www.amis.monde-diplomatique.fr/
# 50 links found
# Queue Size: 5162
# Thread 9 scraping : http://www.amis.monde-diplomatique.fr/mentions-legales/
# 50 links found
# Queue Size: 5161
# Thread 3 scraping : http://www.amis.monde-diplomatique.fr/contact/
# 50 links found
# Queue Size: 5160
# Thread 5 scraping : http://www.amis.monde-diplomatique.fr/informations-legales/
# 0 emails found
# 0 emails found
# 50 links found
# 0 emails found
# Queue Size: 5159
# Thread 0 scraping : http://www.amis.monde-diplomatique.fr/index.php/contact/
# 50 links found
# Queue Size: 5158
# Thread 8 scraping : http://www.amis.monde-diplomatique.fr/mentions.html
# 50 links found
# Queue Size: 5157
# Thread 4 scraping : http://www.amis.monde-diplomatique.fr/politique-de-confidentialite/
# 0 emails found
# 50 links found
# Queue Size: 5159
# Thread 1 scraping : http://www.amis.monde-diplomatique.fr/contact.php/
# 0 emails found
# 0 emails found
# 0 emails found0 emails found
# 50 links found
#
# 50 links foundQueue Size: 5173
# Thread 5 scraping : http://www.amis.monde-diplomatique.fr/contact.htm/
#
# Queue Size: 5188
# Thread 9 scraping : http://www.amis.monde-diplomatique.fr/contacts.html/
# 50 links found
# Queue Size: 5201
# Thread 3 scraping : http://www.amis.monde-diplomatique.fr/contact.html/
# 50 links found
# Queue Size: 5222
# Thread 2 scraping : http://www.amis.monde-diplomatique.fr/cgv/
# 0 emails found
# 50 links found
# Queue Size: 5225
# Thread 8 scraping : https://mamot.fr/@mdiplo
# 0 emails found
# 50 links found
# Queue Size: 5235
# Thread 4 scraping : https://mamot.fr/mentions-legales/
# 0 emails found
# 50 links found
# Queue Size: 5240
# Thread 1 scraping : https://mamot.fr/contact/
# 0 emails found
# 50 links found
# Queue Size: 5239
# Thread 0 scraping : https://mamot.fr/informations-legales/
# 0 emails found
# 50 links found
# Queue Size: 5238
# Thread 9 scraping : https://mamot.fr/index.php/contact/
# 0 emails found
# 0 emails found0 emails found50 links found
# Queue Size: 5237
# Thread 2 scraping : https://mamot.fr/mentions.html
#
#
# 50 links found
# Queue Size: 5236
# 50 links found
# Thread 5 scraping : https://mamot.fr/politique-de-confidentialite/
# Queue Size: 5235
# Thread 3 scraping : https://mamot.fr/contact.php/
# 0 emails found
# Queue Size: 5234
# Thread 4 scraping : https://mamot.fr/contact.htm/
# 0 emails found
# Queue Size: 5233
# Thread 9 scraping : https://mamot.fr/contacts.html/
# 0 emails found
# Queue Size: 5232
# Thread 0 scraping : https://mamot.fr/contact.html/0 emails found
#
# Queue Size: 52310 emails found
# Thread 1 scraping : https://mamot.fr/cgv/
#
# Queue Size: 5230
# Thread 2 scraping : https://indymotion.fr/accounts/monde_diplomatique/video-channels
# 0 emails found
# Queue Size: 5229
# Thread 5 scraping : https://indymotion.fr/mentions-legales/
# 0 emails found
# Queue Size: 5228
# Thread 3 scraping : https://indymotion.fr/contact/
# 1 emails found
# 50 links found
# Queue Size: 5267
# Thread 8 scraping : https://indymotion.fr/informations-legales/
# 0 emails found
# Queue Size: 5266
# Thread 4 scraping : https://indymotion.fr/index.php/contact/
# 0 emails found
# Queue Size: 5265
# Thread 1 scraping : https://indymotion.fr/mentions.html
# 0 emails found0 emails found
# Queue Size: 5264
# Thread 0 scraping : https://indymotion.fr/politique-de-confidentialite/
#
# Queue Size: 5263
# Thread 9 scraping : https://indymotion.fr/contact.php/
# 0 emails found
# 50 links found
# Queue Size: 5277
# Thread 8 scraping : https://indymotion.fr/contact.htm/
# 0 emails found
# 50 links found
# Queue Size: 5276
# Thread 5 scraping : https://indymotion.fr/contacts.html/
# 0 emails found
# 50 links found
# Queue Size: 5275
# Thread 4 scraping : https://indymotion.fr/contact.html/
# 0 emails found
# 50 links found
# Queue Size: 5274
# Thread 2 scraping : https://indymotion.fr/cgv/
# 0 emails found
# 50 links found
# Queue Size: 5273
# Thread 1 scraping : https://framasphere.org/u/mdiplo
# 0 emails found
# 0 emails found50 links found
# Queue Size: 5272
# Thread 3 scraping : https://framasphere.org/mentions-legales/
#
# 0 emails found50 links found
#
# Queue Size: 5271
# Thread 9 scraping : https://framasphere.org/contact/
# 50 links found
# Queue Size: 5270
# Thread 0 scraping : https://framasphere.org/informations-legales/
# 0 emails found
# 50 links found
# Queue Size: 5269
# Thread 8 scraping : https://framasphere.org/index.php/contact/
# 0 emails found
# 50 links found
# Queue Size: 5268
# Thread 5 scraping : https://framasphere.org/mentions.html
# 0 emails found
# 50 links found
# Queue Size: 5267
# Thread 4 scraping : https://framasphere.org/politique-de-confidentialite/
# 0 emails found
# 50 links found
# Queue Size: 5266
# Thread 2 scraping : https://framasphere.org/contact.php/
# 0 emails found
# 50 links found
# Queue Size: 5266
# Thread 0 scraping : https://framasphere.org/contact.htm/
# 0 emails found
# 50 links found
# Queue Size: 5266
# Thread 8 scraping : https://framasphere.org/contacts.html/
# 0 emails found
# 50 links found
# Queue Size: 5266
# Thread 3 scraping : https://framasphere.org/contact.html/
# 0 emails found
# 50 links found
# Queue Size: 5266
# Thread 9 scraping : https://framasphere.org/cgv/
# 0 emails found
# 50 links found
# Queue Size: 5266
# Thread 4 scraping : http://seenthis.net/people/mdiplo
# 0 emails found
# 50 links found
# Queue Size: 5266
# Thread 2 scraping : http://seenthis.net/mentions-legales/
# 0 emails found0 emails found
# 0 emails found
# 50 links found
#
# 50 links found
# Queue Size: 5315
# Thread 5 scraping : http://seenthis.net/contact/
# 0 emails found
# 50 links found
# 0 emails found
# 50 links found
# 50 links found
# 0 emails found
# Queue Size: 5316
# Thread 3 scraping : http://seenthis.net/informations-legales/
# Queue Size: 5315
# Thread 9 scraping : http://seenthis.net/index.php/contact/
# Queue Size: 5315
# Thread 0 scraping : http://seenthis.net/mentions.html
# Queue Size: 5314
# Thread 1 scraping : http://seenthis.net/politique-de-confidentialite/
# 50 links found
# Queue Size: 5313
# Thread 8 scraping : http://seenthis.net/contact.php/
# 0 emails found
# 50 links found
# Queue Size: 5333
# Thread 2 scraping : http://seenthis.net/contact.htm/
# 0 emails found
# Queue Size: 5332
# Thread 0 scraping : http://seenthis.net/contacts.html/
# 0 emails found0 emails found
#
# 50 links found50 links found
# Queue Size: 5339
# Thread 3 scraping : http://seenthis.net/contact.html/
#
# Queue Size: 5346
# Thread 1 scraping : http://seenthis.net/cgv/
# 0 emails found
# 0 emails found50 links found
# Queue Size: 5353
# Thread 5 scraping : http://www.monde-diplomatique.fr/abo
# 0 emails found
#
# 0 emails found
# 50 links found
# Queue Size: 5443
# Thread 8 scraping : http://www.monde-diplomatique.fr/int
# 50 links found
# Queue Size: 5495
# Thread 9 scraping : http://www.monde-diplomatique.fr/images_reseaux/Le_Monde_Diplomatique-premier-site-de-presse-en-ligne-en-1995.jpg
# 50 links found
# Queue Size: 5497
# Thread 4 scraping : http://www.monde-diplomatique.fr/cartes/afrique-securite
# 0 emails found
# 0 emails found
# 0 emails found50 links found
# Queue Size: 549650 links found
#
# 50 links found
#
# Thread 3 scraping : https://www.lemonde.fr/
# Queue Size: 5495
# Thread 1 scraping : https://www.lemonde.fr/mentions-legales/
# Queue Size: 5494
# Thread 2 scraping : https://www.lemonde.fr/contact/
# 0 emails found
# 50 links found
# Queue Size: 5493
# Thread 0 scraping : https://www.lemonde.fr/informations-legales/
# 0 emails found
# 0 emails found
# 0 emails found
# 50 links found
# Queue Size: 5616
# Thread 1 scraping : https://www.lemonde.fr/index.php/contact/
# 0 emails found0 emails found
#
# 50 links found50 links found50 links found
# Queue Size: 5698
# Thread 0 scraping : https://www.lemonde.fr/mentions.html
#
# Queue Size: 5757
# Thread 3 scraping : https://www.lemonde.fr/politique-de-confidentialite/
#
# Queue Size: 5757
# Thread 4 scraping : https://www.lemonde.fr/contact.php/
# 50 links found
# Queue Size: 5756
# Thread 8 scraping : https://www.lemonde.fr/contact.htm/
# 0 emails found
# Queue Size: 5755
# Thread 1 scraping : https://www.lemonde.fr/contacts.html/
# 0 emails found
# Queue Size: 5754
# Thread 4 scraping : https://www.lemonde.fr/contact.html/
# 0 emails found0 emails found
#
# 0 emails found
# 50 links found
# 0 emails found
# Queue Size: 5753
# Thread 5 scraping : https://www.lemonde.fr/cgv/
# 50 links found
# Queue Size: 5806
# Thread 8 scraping : https://moncompte.lemonde.fr/
# 50 links found50 links found
# Queue Size: 5824
# Thread 0 scraping : https://moncompte.lemonde.fr/mentions-legales/
#
# Queue Size: 5836
# Thread 3 scraping : https://moncompte.lemonde.fr/contact/
# 0 emails found
# 50 links found0 emails found
# 0 emails found
#
# Queue Size: 5835
# Thread 1 scraping : https://moncompte.lemonde.fr/informations-legales/
# 50 links found
# Queue Size: 5863
# Thread 2 scraping : https://moncompte.lemonde.fr/index.php/contact/
# 50 links found
# Queue Size: 5875
# Thread 4 scraping : https://moncompte.lemonde.fr/mentions.html
# 0 emails found
# 50 links found
# Queue Size: 5882
# Thread 0 scraping : https://moncompte.lemonde.fr/politique-de-confidentialite/
# 4 emails found
# 50 links found
# Queue Size: 5921
# Thread 5 scraping : https://moncompte.lemonde.fr/contact.php/
# 0 emails found
# 50 links found
# 0 emails found
# Queue Size: 5920
# Thread 5 scraping : https://moncompte.lemonde.fr/contact.htm/
# Queue Size: 5934
# Thread 3 scraping : https://moncompte.lemonde.fr/contacts.html/
# 0 emails found
# 0 emails found
# 50 links found50 links found
# Queue Size: 5934
# Thread 8 scraping : https://moncompte.lemonde.fr/contact.html/
#
# Queue Size: 59340 emails found
# Thread 2 scraping : https://moncompte.lemonde.fr/cgv/
#
# 0 emails found
# 50 links found
# Queue Size: 5934
# Thread 0 scraping : http://blog.mondediplo.net
# 50 links found
# Queue Size: 5934
# Thread 1 scraping : http://blog.mondediplo.net/mentions-legales/
# 0 emails found
# 50 links found
# Queue Size: 5934
# Thread 4 scraping : http://blog.mondediplo.net/contact/
# 0 emails found0 emails found
#
# 4 emails found50 links found
# Queue Size: 5934
# Thread 5 scraping : http://blog.mondediplo.net/informations-legales/
# 50 links found
# Queue Size: 5934
# Thread 3 scraping : http://blog.mondediplo.net/index.php/contact/
#
# 50 links found
# Queue Size: 5949
# Thread 2 scraping : http://blog.mondediplo.net/mentions.html
# 0 emails found
# 50 links found
# Queue Size: 6104
# Thread 0 scraping : http://blog.mondediplo.net/politique-de-confidentialite/
# 0 emails found
# 0 emails found
# 50 links found
# Queue Size: 6108
# Thread 4 scraping : http://blog.mondediplo.net/contact.php/
# 50 links found
# Queue Size: 6108
# Thread 1 scraping : http://blog.mondediplo.net/contact.htm/
# 0 emails found
# Queue Size: 6107
# Thread 4 scraping : http://blog.mondediplo.net/contacts.html/
# 0 emails found
# Queue Size: 6106
# Thread 1 scraping : http://blog.mondediplo.net/contact.html/
# 0 emails found
# 0 emails found
# 50 links found
# Queue Size: 6106
# Thread 8 scraping : http://blog.mondediplo.net/cgv/50 links found
#
# Queue Size: 6106
# Thread 5 scraping : https://boutique.monde-diplomatique.fr/mentions-legales/
# ...
# Queue Size: 9839
# Thread 3 scraping : https://www.lmd.no/lmd/lmd2/litteratur/
# 4 emails found
# 50 links found
# Queue Size: 9839
# Thread 7 scraping : https://www.lmd.no/lmd/verden/europa/frankrike/
# 4 emails found
# 50 links found
# Queue Size: 9838
# Thread 9 scraping : https://www.lmd.no/author/damien-lefauconnier/
# 4 emails found4 emails found
#
# 4 emails found
# 50 links found
# Queue Size: 9837
# Thread 1 scraping : https://www.lmd.no/author/etienne-decroly/
# 4 emails found
# 4 emails found
# 4 emails found50 links found
#
# Queue Size: 9837
# Thread 0 scraping : https://www.lmd.no/lmd/kart/
# 50 links found
# Queue Size: 9836
# Thread 2 scraping : https://www.lmd.no/author/steffen-moestrup/
# 4 emails found
# 50 links found
# Queue Size: 9835
# Thread 3 scraping : https://www.lmd.no/min-side/
# 50 links found
# Queue Size: 9834
# Thread 5 scraping : https://www.lmd.no/abon/
# 50 links found50 links found
# Queue Size: 9833
# Thread 9 scraping : https://www.lmd.no/lmd/lmd2/film/dokumentar/
#
# Queue Size: 9832
# Thread 7 scraping : https://www.lmd.no/2022/03/hvordan-telle-utilsiktede-ofre/
# 4 emails found
# 4 emails found
# 50 links found
# Queue Size: 9831
# Thread 1 scraping : https://twitter.com/lmd_no
# 4 emails found
# 4 emails found
# 4 emails found50 links found
# Queue Size: 9830
# Thread 0 scraping : https://www.lmd.no/
#
# 4 emails found
# 50 links found
# Queue Size: 9829
# Thread 2 scraping : https://www.lmd.no/kassen/
# 50 links found
# Queue Size: 9828
# Thread 7 scraping : https://www.lmd.no/2022/04/faraovaskingen-av-sisis-autoritaere-regime/
# 0 emails found
# 50 links found50 links found
# Queue Size: 9827
# Thread 5 scraping : https://www.lmd.no/2022/03/hva-skal-vi-med-sanksjoner-hvis-de-ikke-hindrer-kriger/
#
# Queue Size: 9826
# Thread 1 scraping : https://www.lmd.no/2022/03/genredigeringens-uregulerte-farer/
# 4 emails found50 links found
# Queue Size: 9825
# Thread 9 scraping : http://www.lmd.nomailto:mira@lmd.no
#
# 50 links found
# Queue Size: 9824
# Thread 3 scraping : http://www.lmd.nomailto:mira@lmd.no/mentions-legales/
# 4 emails found
# 4 emails found
# 4 emails found
# 4 emails found
# 50 links found
# Queue Size: 9823
# Thread 7 scraping : http://www.lmd.nomailto:mira@lmd.no/contact/
# 50 links found
# Queue Size: 9822
# Thread 0 scraping : http://www.lmd.nomailto:mira@lmd.no/informations-legales/
# 50 links found
# Queue Size: 9821
# 4 emails found
# Thread 1 scraping : http://www.lmd.nomailto:mira@lmd.no/index.php/contact/
# 50 links found
# 50 links found
# Queue Size: 9820
# Thread 2 scraping : http://www.lmd.nomailto:mira@lmd.no/mentions.html
# Queue Size: 9820
# Thread 5 scraping : http://www.lmd.nomailto:mira@lmd.no/politique-de-confidentialite/
# 4 emails found
# 50 links found
# Queue Size: 9823
# Thread 3 scraping : http://www.lmd.nomailto:mira@lmd.no/contact.php/
# 4 emails found
# 50 links found
# Queue Size: 9835
# Thread 9 scraping : http://www.lmd.nomailto:mira@lmd.no/contact.htm/
# 4 emails found
# 4 emails found
# 4 emails found
# 4 emails found
# 4 emails found
# 50 links found
# Queue Size: 9840
# Thread 5 scraping : http://www.lmd.nomailto:mira@lmd.no/contacts.html/
# 50 links found
# Queue Size: 9843
# Thread 2 scraping : http://www.lmd.nomailto:mira@lmd.no/contact.html/
# 50 links found
# Queue Size: 9846
# Thread 1 scraping : http://www.lmd.nomailto:mira@lmd.no/cgv/
# 50 links found
# 50 links found
# Queue Size: 9848
# Thread 7 scraping : https://www.lmd.no/2022/04/uventet-tysk-opprustning/
# Queue Size: 9851
# Thread 0 scraping : https://www.lmd.no/lmd/lmd2/
# 4 emails found
# 4 emails found
# 4 emails found
# 50 links found
# Queue Size: 9850
# Thread 0 scraping : https://www.lmd.no/lmd/verden/afrika/
# 50 links found
# Queue Size: 985450 links found
#
# Thread 3 scraping : https://www.lmd.no/2022/04/fransk-nederlag-i-sahel/
# Queue Size: 9853
# Thread 7 scraping : https://www.lmd.no/2022/04/de-riktige-flyktningene/
# 4 emails found
# 50 links found
# Queue Size: 9855
# Thread 9 scraping : https://www.lmd.no/2022/04/en-helt-alminnelig-mann/
# 4 emails found
# 4 emails found4 emails found
#
# 4 emails found
# 4 emails found
# 4 emails found
# 4 emails found
# 50 links found50 links found
# Queue Size: 9857
# Thread 5 scraping : https://www.lmd.no/author/cecile-marin/
# 50 links found
# Queue Size: 9857
#
# Thread 3 scraping : https://www.lmd.no/author/clementine-metenier/
# Queue Size: 9856
# Thread 7 scraping : https://www.lmd.no/lmd/verden/asia/
# 50 links found
# Queue Size: 9858
# Thread 1 scraping : http://www.lmd.no/contact/mailto:mira@lmd.no
# 50 links found
# Queue Size: 9857
# Thread 0 scraping : https://www.lmd.no/lmd/podkast/
# 50 links found
# Queue Size: 9861
# Thread 2 scraping : http://www.lmd.no/contact/mailto:abo@lmd.no
# 50 links found
# Queue Size: 9861
# Thread 9 scraping : http://www.lmd.no/contact/mailto:remi@lmd.no
# 4 emails found
# 4 emails found
# 4 emails found
# 4 emails found
# 50 links found
# Queue Size: 9860
# Thread 5 scraping : http://www.lmd.no/contact/mailto:redaksjon@lmd.no
# 50 links found
# Queue Size: 9859
# Thread 0 scraping : https://www.lmd.no/ikke-mottatt-avis/
# 50 links found
# Queue Size: 9858
# Thread 3 scraping : https://www.lmd.no/produkt/kvartalsabonnement/
# 50 links found
# Queue Size: 9857
# Thread 7 scraping : https://www.lmd.no/lmd/lmd2/filosofi/
# 4 emails found
# 50 links found
# Queue Size: 9857
# Thread 2 scraping : http://www.lmd.no/contact/tel:004747465880
# 4 emails found
# 4 emails found
# 50 links found
# Queue Size: 9856
# Thread 1 scraping : https://www.lmd.no/lmd/lmd2/film/
# 4 emails found
# 4 emails found
# 4 emails found
# 50 links found
# Queue Size: 9855
# Thread 9 scraping : https://www.lmd.no/annonser-2/
# 50 links found
# Queue Size: 9854
# Thread 0 scraping : https://nb-no.facebook.com/lmd.no/
# 50 links found
# Queue Size: 9853
# Thread 3 scraping : https://nb-no.facebook.com/mentions-legales/
# 50 links found
# Queue Size: 9852
# Thread 7 scraping : https://nb-no.facebook.com/contact/
# 0 emails found
# 0 emails found
# 50 links found4 emails found50 links found
#
# Queue Size: 9876
# Thread 7 scraping : https://nb-no.facebook.com/informations-legales/
#
# Queue Size: 9883
# 6 emails found
# Thread 3 scraping : https://nb-no.facebook.com/index.php/contact/
# 0 emails found
# Queue Size: 9882
# Thread 0 scraping : https://nb-no.facebook.com/mentions.html
# 4 emails found
# 50 links found
# Queue Size: 9881
# 50 links found
# Thread 5 scraping : https://nb-no.facebook.com/politique-de-confidentialite/
# Queue Size: 9880
# Thread 9 scraping : https://nb-no.facebook.com/contact.php/
# 50 links found
# Queue Size: 9879
# Thread 1 scraping : https://nb-no.facebook.com/contact.htm/
# 4 emails found
# 0 emails found
# 50 links found
# Queue Size: 9881
# Thread 7 scraping : https://nb-no.facebook.com/contacts.html/
# 0 emails found
# 0 emails found
# 0 emails found
# 50 links found50 links found
# Queue Size: 9880
# Thread 2 scraping : https://nb-no.facebook.com/contact.html/
# 50 links found
# Queue Size: 9883
# Thread 0 scraping : https://nb-no.facebook.com/cgv/
#
# 0 emails found
# Queue Size: 9885
# Thread 9 scraping : http://www.lmd.no/mentions-legales/mailto:redaksjon@lmd.no50 links found
# 50 links found
#
# 0 emails found
# Queue Size: 9887
# Thread 1 scraping : https://www.lmd.no/lmd/lmd2/kunst/
# Queue Size: 9886
# Thread 3 scraping : http://www.lmd.no/mentions-legales/
# 50 links found
# Queue Size: 9886
# Thread 5 scraping : https://www.lmd.no/produkt/gaveabonnement/
# 0 emails found
# 50 links found
# 0 emails foundQueue Size: 9886
# 50 links found0 emails found
#
# 50 links found
#
# Thread 0 scraping : http://www.lmd.no/mentions-legales/mailto:remi@lmd.no
# Queue Size: 9889
# Thread 2 scraping : http://www.lmd.no/mentions-legales/tel:004747465880
# Queue Size: 9897
# Thread 7 scraping : http://www.lmd.no/mentions-legales/mailto:abo@lmd.no
# 4 emails found
# 50 links found4 emails found
#
# Queue Size: 9896
# Thread 5 scraping : https://www.lmd.no/produktkategori/eavis/
# 50 links found
# Queue Size: 9895
# Thread 1 scraping : http://www.lmd.no/informations-legales/mailto:remi@lmd.no
# 4 emails found
# 50 links found
# Queue Size: 9894
# Thread 3 scraping : http://www.lmd.no/informations-legales/mailto:abo@lmd.no
# 4 emails found
# 4 emails found
# 50 links found
# 50 links found
# Queue Size: 9893
# Thread 9 scraping : http://www.lmd.no/informations-legales/
# Queue Size: 9892
# Thread 5 scraping : http://www.lmd.no/informations-legales/mailto:redaksjon@lmd.no
# 4 emails found
# 50 links found
# Queue Size: 9892
# Thread 2 scraping : http://www.lmd.no/index.php/contact/
# 4 emails found4 emails found
#
# 50 links found
# Queue Size: 9891
# Thread 0 scraping : http://www.lmd.no/index.php/contact/mailto:abo@lmd.no
# 50 links found
# Queue Size: 9890
# Thread 7 scraping : http://www.lmd.no/index.php/contact/mailto:redaksjon@lmd.no
# 4 emails found
# 50 links found
# Queue Size: 9890
# Thread 1 scraping : http://www.lmd.no/index.php/contact/tel:004747465880
# 4 emails found4 emails found
#
# 50 links found
# Queue Size: 9890
# Thread 9 scraping : http://www.lmd.no/index.php/contact/mailto:remi@lmd.no
# 50 links found
# Queue Size: 9889
# Thread 3 scraping : http://www.lmd.no/mailto:abo@lmd.no
# 4 emails found
# 50 links found
# Queue Size: 9889
# Thread 2 scraping : http://www.lmd.no/mailto:mira@lmd.no
# 4 emails found
# 50 links found
# Queue Size: 9888
# Thread 5 scraping : http://www.lmd.no/politique-de-confidentialite/mailto:abo@lmd.no
# 4 emails found
# 50 links found
# Queue Size: 9887
# Thread 0 scraping : http://www.lmd.no/politique-de-confidentialite/
# 4 emails found
# 4 emails found
# 50 links found
# Queue Size: 9886
# Thread 7 scraping : http://www.lmd.no/politique-de-confidentialite/mailto:redaksjon@lmd.no
# 50 links found
# Queue Size: 9885
# Thread 1 scraping : http://www.lmd.no/contact.php/mailto:mira@lmd.no
# 4 emails found4 emails found
#
# 50 links found
# Queue Size: 9886
# Thread 3 scraping : http://www.lmd.no/contact.php/
# 50 links found
# Queue Size: 9885
# Thread 9 scraping : http://www.lmd.no/contact.php/mailto:redaksjon@lmd.no
# 4 emails found
# 50 links found
# Queue Size: 9885
# Thread 2 scraping : http://www.lmd.no/contact.htm/mailto:mira@lmd.no
# 4 emails found
# 50 links found
# Queue Size: 9886
# Thread 5 scraping : http://www.lmd.no/contact.htm/mailto:abo@lmd.no
# 4 emails found
# 50 links found
# Queue Size: 9885
# Thread 0 scraping : http://www.lmd.no/contact.htm/
# 4 emails found
# 50 links found
# Queue Size: 9886
# Thread 3 scraping : http://www.lmd.no/contact.htm/mailto:redaksjon@lmd.no
# 4 emails found
# 4 emails found
# 4 emails found
# 4 emails found
# 50 links found
# Queue Size: 9885
# Thread 7 scraping : http://www.lmd.no/contact.htm/tel:004747465880
# 4 emails found
# 50 links found
# Queue Size: 98844 emails found
# 50 links found
# Thread 9 scraping : http://www.lmd.no/contact.htm/mailto:remi@lmd.no
#
# 50 links foundQueue Size: 9883
# Thread 0 scraping : http://www.lmd.no/contacts.html/
#
# 50 links found
# Queue Size: 9882
# Thread 2 scraping : http://www.lmd.no/contacts.html/tel:004747465880
# Queue Size: 9882
# Thread 1 scraping : http://www.lmd.no/contacts.html/mailto:redaksjon@lmd.no
# 50 links found
# Queue Size: 9881
# Thread 5 scraping : http://www.lmd.no/contact.html/
# 4 emails found
# 50 links found
# Queue Size: 9880
# Thread 3 scraping : http://www.lmd.no/contact.html/mailto:abo@lmd.no
# 4 emails found
# 50 links found
# Queue Size: 9881
# Thread 0 scraping : http://www.lmd.no/contact.html/mailto:remi@lmd.no
# 4 emails found
# 50 links found
# Queue Size: 9881
# Thread 5 scraping : http://www.lmd.no/contact.html/tel:004747465880
# 4 emails found
# 50 links found
# Queue Size: 9880
# Thread 7 scraping : http://www.lmd.no/contact.html/mailto:mira@lmd.no
# 4 emails found4 emails found
#
# 4 emails found
# 50 links found
# Queue Size: 9880
# Thread 1 scraping : http://www.lmd.no/cgv/tel:004747465880
# 50 links found
# Queue Size: 9879
# Thread 9 scraping : http://www.lmd.no/cgv/
# 50 links found
# Queue Size: 9878
# Thread 2 scraping : http://www.lmd.no/cgv/mailto:remi@lmd.no
# 4 emails found
# 50 links found
# Queue Size: 9877
# Thread 3 scraping : http://www.lmd.no/cgv/mailto:mira@lmd.no
# 4 emails found
# 4 emails found
# 50 links found
# Queue Size: 9876
# Thread 0 scraping : https://support.cloudflare.com/hc/en-us/articles/200171906-Error-522
# 4 emails found
# 50 links found
# Queue Size: 9877
# Thread 9 scraping : https://support.cloudflare.com/mentions-legales/
# 50 links found
# Queue Size: 9876
# Thread 5 scraping : https://support.cloudflare.com/contact/
# 0 emails found
# 0 emails found
# 50 links found
# Queue Size: 9875
# Thread 0 scraping : https://support.cloudflare.com/informations-legales/
# 50 links found
# Queue Size: 9874
# Thread 5 scraping : https://support.cloudflare.com/index.php/contact/
# 4 emails found
# 0 emails found
# 50 links found
# Queue Size: 9873
# Thread 9 scraping : https://support.cloudflare.com/mentions.html
# 4 emails found
# 4 emails found
# 50 links found
# Queue Size: 9872
# Thread 7 scraping : https://support.cloudflare.com/politique-de-confidentialite/
# 50 links found
# Queue Size: 9871
# Thread 2 scraping : https://support.cloudflare.com/contact.php/
# 50 links found
# 0 emails foundQueue Size: 9870
# Thread 1 scraping : https://support.cloudflare.com/contact.htm/
#
# 50 links found
# 0 emails found
# 50 links found
# Queue Size: 9869
# Thread 5 scraping : https://support.cloudflare.com/contacts.html/
# 0 emails found
# 50 links found
# Queue Size: 9868
# Thread 0 scraping : https://support.cloudflare.com/contact.html/
# Queue Size: 9867
# Thread 9 scraping : https://support.cloudflare.com/cgv/
# 0 emails found0 emails found
# 50 links found
#
# Queue Size: 986650 links found
# 0 emails found0 emails found4 emails found
#
# Thread 0 scraping : https://www.cloudflare.com/5xx-error-landing
# Queue Size: 9865
# Thread 5 scraping : https://www.cloudflare.com/mentions-legales/
# 0 emails found
# 50 links found
# Queue Size: 9864
# Thread 7 scraping : https://www.cloudflare.com/contact/0 emails found
#
#
# 50 links found
# 50 links found
#
# 50 links foundQueue Size: 9863
#
# Thread 9 scraping : https://www.cloudflare.com/informations-legales/
# Queue Size: 9862
# Thread 1 scraping : https://www.cloudflare.com/index.php/contact/
# Queue Size: 9861
# Thread 2 scraping : https://www.cloudflare.com/mentions.html
# 50 links found
# Queue Size: 9860
# Thread 3 scraping : https://www.cloudflare.com/politique-de-confidentialite/
# 0 emails found0 emails found1 emails found
#
#
# 50 links found
# Queue Size: 9859
# Thread 1 scraping : https://www.cloudflare.com/contact.php/
# 50 links found
# Queue Size: 9858
# Thread 7 scraping : https://www.cloudflare.com/contact.htm/
# 50 links found
# Queue Size: 9868
# Thread 0 scraping : https://www.cloudflare.com/contacts.html/
# 0 emails found
# 50 links found
# Queue Size: 9867
# Thread 1 scraping : https://www.cloudflare.com/contact.html/
# 1 emails found
# 50 links found
# Queue Size: 9965
# Thread 9 scraping : https://www.cloudflare.com/cgv/
# 1 emails found1 emails found
#
# 1 emails found1 emails found
#
# 1 emails found1 emails found
#
# 1 emails found
# 50 links found
# Queue Size: 10002
# Thread 0 scraping : http://www.woz.ch/
# 50 links found
# Queue Size: 10042
# Thread 5 scraping : http://www.woz.ch/t/schweiz
# 50 links found
# Queue Size: 10073
# Thread 3 scraping : http://www.woz.ch/info/woz
# 50 links found
# Queue Size: 10102
# Thread 2 scraping : http://www.woz.ch/archiv
# 50 links found
# Queue Size: 10102
# Thread 1 scraping : http://www.woz.ch/abo/bestellen
# 50 links found
# Queue Size: 10103
# Thread 7 scraping : http://www.woz.ch/lmd
# 50 links found
# Queue Size: 10102
# Thread 9 scraping : http://www.woz.ch/shop
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-5ac755c23ec7> in <module>()
#     195 scraper = ScrapingEmails(url, scope)
#     196 scraper.pre_run()
# --> 197 scraper.post_run()
#
# <ipython-input-4-5ac755c23ec7> in post_run(self)
#     150     def post_run(self):
#     151         for thread in self.threads:
# --> 152             thread.join()
#     153
#     154
#
# /usr/lib/python3.7/threading.py in join(self, timeout)
#    1042
#    1043         if timeout is None:
# -> 1044             self._wait_for_tstate_lock()
#    1045         else:
#    1046             # the behavior of a negative timeout isn't documented, but
#
# /usr/lib/python3.7/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1058         if lock is None:  # already determined that the C code is done
#    1059             assert self._is_stopped
# -> 1060         elif lock.acquire(block, timeout):
#    1061             lock.release()
#    1062             self._stop()
#
# KeyboardInterrupt:
